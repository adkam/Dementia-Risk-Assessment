# %% [markdown]
# # Partial Visualization

# %%
import sys
import pyecharts
import pyecharts.options as opts
from pyecharts.charts import Grid, Boxplot, Line, Tab
from pyecharts.commons.utils import JsCode
from pyecharts.globals import ThemeType

# %% [markdown]
# ### Line Chart for Model 5 & 6

# %%
def box_plot(data, title = "Final Tree Model Evaluation"):
    '''
    Box plot to visualize variation and distribution
    '''
    if len(data) == 2:
        box = Boxplot(init_opts = opts.InitOpts(theme = ThemeType.VINTAGE))
        box = box.add_xaxis(xaxis_data = ['ROC', 'Accuracy']
                ).add_yaxis(series_name = '', y_axis = box.prepare_data(data)
                ).set_global_opts(title_opts = opts.TitleOpts(pos_left = 'center', 
                                                          title = title),
                              tooltip_opts = opts.TooltipOpts(trigger = 'item', axis_pointer_type = 'shadow'),
                              xaxis_opts = opts.AxisOpts(type_ = 'category', boundary_gap = True,
                                                         splitarea_opts = opts.SplitAreaOpts(is_show = False),
                                                         axislabel_opts = opts.LabelOpts(formatter = '{value}'),
                                                         splitline_opts = opts.SplitLineOpts(is_show = False),
                                                        ),
                              yaxis_opts = opts.AxisOpts(type_ = 'value',
                                                         name = '',
                                                         splitarea_opts = opts.SplitAreaOpts(is_show = True,
                                                                                         areastyle_opts = opts.AreaStyleOpts(opacity = 1)
                                                                                        ),
                                                        ),
                 ).set_series_opts(tooltip_opts = opts.TooltipOpts(formatter = JsCode('''function(p){return p.name+'<br>'+'Min: '+
                                                                                     p.value[1]+'<br>1st Quantile: '+p.value[2]+'<br>Median: '+p.value[3]+
                                                                                     '<br>3rd Quantile: '+p.value[4]+'<br>Max: '+p.value[5]}''')))

    
    if len(data) == 4:
        box = Boxplot(init_opts = opts.InitOpts(theme = ThemeType.VINTAGE))
        box = box.add_xaxis(xaxis_data = ['Accuracy', 'Precision', 'Sensitivity', 'Specificity']
                ).add_yaxis(series_name = '', y_axis = box.prepare_data(data)
                ).set_global_opts(title_opts = opts.TitleOpts(pos_left = 'center', 
                                                          title = title),
                              tooltip_opts = opts.TooltipOpts(trigger = 'item', axis_pointer_type = 'shadow'),
                              xaxis_opts = opts.AxisOpts(type_ = 'category', boundary_gap = True,
                                                         splitarea_opts = opts.SplitAreaOpts(is_show = False),
                                                         axislabel_opts = opts.LabelOpts(formatter = '{value}'),
                                                         splitline_opts = opts.SplitLineOpts(is_show = False),
                                                        ),
                              yaxis_opts = opts.AxisOpts(type_ = 'value',
                                                         name = '',
                                                         splitarea_opts = opts.SplitAreaOpts(is_show = True,
                                                                                         areastyle_opts = opts.AreaStyleOpts(opacity = 1)
                                                                                        ),
                                                        ),
                 ).set_series_opts(tooltip_opts = opts.TooltipOpts(formatter = JsCode('''function(p){return p.name+'<br>'+'Min: '+
                                                                                     p.value[1]+'<br>1st Quantile: '+p.value[2]+'<br>Median: '+p.value[3]+
                                                                                     '<br>3rd Quantile: '+p.value[4]+'<br>Max: '+p.value[5]}''')))
     
    return box

# %% [markdown]
# ###### prepare for data

# %%
roc = [0.5499999999999999, 0.325, 0.7750000000000001, 0.525, 0.525, 0.2, 0.7, 0.4666666666666666, 0.375, 0.625, 0.6500000000000001, 0.5499999999999999, 0.625, 0.475, 0.425, 0.6500000000000001, 0.6333333333333333, 0.6333333333333333, 0.375, 0.625, 0.4, 0.525, 0.5499999999999999, 0.575, 0.525, 0.2, 0.4, 0.7333333333333333, 0.5, 0.75, 0.3, 0.425, 0.425, 0.7750000000000001, 0.4, 0.75, 0.6666666666666666, 0.5666666666666667, 0.875, 0.375, 0.625, 0.2, 0.525, 0.09999999999999998, 0.6500000000000001, 0.5, 0.2666666666666666, 0.36666666666666664, 0.75, 0.625]
acc = [0.5555555555555556, 0.3333333333333333, 0.7777777777777778, 0.5555555555555556, 0.5555555555555556, 0.2222222222222222, 0.625, 0.5, 0.375, 0.625, 0.6666666666666666, 0.5555555555555556, 0.6666666666666666, 0.4444444444444444, 0.4444444444444444, 0.6666666666666666, 0.625, 0.625, 0.375, 0.625, 0.4444444444444444, 0.5555555555555556, 0.5555555555555556, 0.5555555555555556, 0.5555555555555556, 0.2222222222222222, 0.5, 0.75, 0.5, 0.75, 0.3333333333333333, 0.4444444444444444, 0.4444444444444444, 0.7777777777777778, 0.4444444444444444, 0.7777777777777778, 0.75, 0.625, 0.875, 0.375, 0.6666666666666666, 0.2222222222222222, 0.5555555555555556, 0.1111111111111111, 0.6666666666666666, 0.5555555555555556, 0.25, 0.375, 0.75, 0.625]

# %% [markdown]
# #### Stepwise 1 forward Model

# %%
box = box_plot([roc, acc], 'First Stepwise Forward Model')
box.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="8786662fa5b04df48c0df34ee45263db" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_8786662fa5b04df48c0df34ee45263db = echarts.init(
#                     document.getElementById('8786662fa5b04df48c0df34ee45263db'), 'vintage', {renderer: 'canvas'});
#                 var option_8786662fa5b04df48c0df34ee45263db = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "boxplot",
#             "data": [
#                 [
#                     0.09999999999999998,
#                     0.4,
#                     0.525,
#                     0.6375,
#                     0.875
#                 ],
#                 [
#                     0.1111111111111111,
#                     0.4444444444444444,
#                     0.5555555555555556,
#                     0.6666666666666666,
#                     0.875
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "formatter": function(p){return p.name+'<br>'+'Min: '+                                                                                     p.value[1]+'<br>1st Quantile: '+p.value[2]+'<br>Median: '+p.value[3]+                                                                                     '<br>3rd Quantile: '+p.value[4]+'<br>Max: '+p.value[5]},
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "shadow"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": true,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": false,
#                 "areaStyle": {
#                     "opacity": 0
#                 }
#             },
#             "data": [
#                 "ROC",
#                 "Accuracy"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": true,
#                 "areaStyle": {
#                     "opacity": 1
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "First Stepwise Forward Model",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_8786662fa5b04df48c0df34ee45263db.setOption(option_8786662fa5b04df48c0df34ee45263db);
#         });
#     </script>

# %% [markdown]
# ###### prepare data

# %%
roc = [0.525, 0.675, 0.6500000000000001, 0.525, 0.625, 0.3, 0.43333333333333324, 0.5666666666666667, 0.5, 0.625, 0.6500000000000001, 0.875, 0.35, 0.6500000000000001, 0.425, 0.6500000000000001, 0.5333333333333333, 0.6333333333333333, 0.375, 0.5, 0.4, 0.5, 0.45000000000000007, 0.9, 0.675, 0.2, 0.4, 0.7333333333333333, 0.25, 0.875, 0.3, 0.6500000000000001, 0.25, 0.9, 0.3, 0.75, 0.6666666666666666, 0.5666666666666667, 0.625, 0.5, 0.625, 0.425, 0.525, 0.325, 0.7750000000000001, 0.525, 0.6333333333333333, 0.36666666666666664, 0.75, 0.5]
acc = [0.5555555555555556, 0.6666666666666666, 0.6666666666666666, 0.5555555555555556, 0.6666666666666666, 0.3333333333333333, 0.375, 0.625, 0.5, 0.625, 0.6666666666666666, 0.8888888888888888, 0.3333333333333333, 0.6666666666666666, 0.4444444444444444, 0.6666666666666666, 0.5, 0.625, 0.375, 0.5, 0.4444444444444444, 0.5555555555555556, 0.4444444444444444, 0.8888888888888888, 0.6666666666666666, 0.2222222222222222, 0.5, 0.75, 0.25, 0.875, 0.3333333333333333, 0.6666666666666666, 0.2222222222222222, 0.8888888888888888, 0.3333333333333333, 0.7777777777777778, 0.75, 0.625, 0.625, 0.5, 0.6666666666666666, 0.4444444444444444, 0.5555555555555556, 0.3333333333333333, 0.7777777777777778, 0.5555555555555556, 0.625, 0.375, 0.75, 0.5]

# %% [markdown]
# #### Stepwise 1 Backward Model

# %%
box = box_plot([roc, acc], 'First Stepwise Backward Model')
box.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="b0a34f071c164eb79bed62d7b88d656b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_b0a34f071c164eb79bed62d7b88d656b = echarts.init(
#                     document.getElementById('b0a34f071c164eb79bed62d7b88d656b'), 'vintage', {renderer: 'canvas'});
#                 var option_b0a34f071c164eb79bed62d7b88d656b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "boxplot",
#             "data": [
#                 [
#                     0.2,
#                     0.41874999999999996,
#                     0.5291666666666667,
#                     0.6500000000000001,
#                     0.9
#                 ],
#                 [
#                     0.2222222222222222,
#                     0.4444444444444444,
#                     0.5555555555555556,
#                     0.6666666666666666,
#                     0.8888888888888888
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "formatter": function(p){return p.name+'<br>'+'Min: '+                                                                                     p.value[1]+'<br>1st Quantile: '+p.value[2]+'<br>Median: '+p.value[3]+                                                                                     '<br>3rd Quantile: '+p.value[4]+'<br>Max: '+p.value[5]},
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "shadow"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": true,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": false,
#                 "areaStyle": {
#                     "opacity": 0
#                 }
#             },
#             "data": [
#                 "ROC",
#                 "Accuracy"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": true,
#                 "areaStyle": {
#                     "opacity": 1
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "First Stepwise Backward Model",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_b0a34f071c164eb79bed62d7b88d656b.setOption(option_b0a34f071c164eb79bed62d7b88d656b);
#         });
#     </script>

# %% [markdown]
# ###### prepare for data

# %%
roc = [0.75, 0.3, 0.7750000000000001, 0.6500000000000001, 0.2, 0.625, 0.4666666666666666, 0.6666666666666666, 0.5, 0.5, 0.575, 0.75, 0.525, 0.4, 0.8, 0.4, 0.4666666666666666, 0.2666666666666666, 0.5, 0.5, 0.875, 0.45000000000000007, 0.625, 0.525, 0.5499999999999999, 0.6500000000000001, 0.4666666666666666, 0.5666666666666667, 0.5, 0.375, 0.4, 0.675, 0.6500000000000001, 0.6500000000000001, 0.6500000000000001, 0.5, 0.36666666666666664, 0.36666666666666664, 0.75, 0.5, 0.4, 0.575, 0.625, 0.5499999999999999, 0.6500000000000001, 0.5, 0.4666666666666666, 0.36666666666666664, 0.75, 0.75]
acc = [0.7777777777777778, 0.3333333333333333, 0.7777777777777778, 0.6666666666666666, 0.2222222222222222, 0.6666666666666666, 0.5, 0.75, 0.5, 0.5, 0.5555555555555556, 0.7777777777777778, 0.5555555555555556, 0.4444444444444444, 0.7777777777777778, 0.4444444444444444, 0.5, 0.25, 0.5, 0.5, 0.8888888888888888, 0.4444444444444444, 0.6666666666666666, 0.5555555555555556, 0.5555555555555556, 0.6666666666666666, 0.5, 0.625, 0.5, 0.375, 0.4444444444444444, 0.6666666666666666, 0.6666666666666666, 0.6666666666666666, 0.6666666666666666, 0.5555555555555556, 0.375, 0.375, 0.75, 0.5, 0.4444444444444444, 0.5555555555555556, 0.6666666666666666, 0.5555555555555556, 0.6666666666666666, 0.5555555555555556, 0.5, 0.375, 0.75, 0.75]

# %% [markdown]
# #### Stepwise 2 Forward Model

# %%
box = box_plot([roc, acc], 'Second Stepwise Forward Model')
box.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="98c5aa4543ae4dabbd434c3aa758a7ec" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_98c5aa4543ae4dabbd434c3aa758a7ec = echarts.init(
#                     document.getElementById('98c5aa4543ae4dabbd434c3aa758a7ec'), 'vintage', {renderer: 'canvas'});
#                 var option_98c5aa4543ae4dabbd434c3aa758a7ec = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "boxplot",
#             "data": [
#                 [
#                     0.2,
#                     0.4625,
#                     0.525,
#                     0.6500000000000001,
#                     0.875
#                 ],
#                 [
#                     0.2222222222222222,
#                     0.4861111111111111,
#                     0.5555555555555556,
#                     0.6666666666666666,
#                     0.8888888888888888
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "formatter": function(p){return p.name+'<br>'+'Min: '+                                                                                     p.value[1]+'<br>1st Quantile: '+p.value[2]+'<br>Median: '+p.value[3]+                                                                                     '<br>3rd Quantile: '+p.value[4]+'<br>Max: '+p.value[5]},
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "shadow"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": true,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": false,
#                 "areaStyle": {
#                     "opacity": 0
#                 }
#             },
#             "data": [
#                 "ROC",
#                 "Accuracy"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": true,
#                 "areaStyle": {
#                     "opacity": 1
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Second Stepwise Forward Model",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_98c5aa4543ae4dabbd434c3aa758a7ec.setOption(option_98c5aa4543ae4dabbd434c3aa758a7ec);
#         });
#     </script>

# %% [markdown]
# ###### prepare for data

# %%
roc = [0.75, 0.425, 0.875, 0.6500000000000001, 0.3, 0.425, 0.5666666666666667, 0.5666666666666667, 0.75, 0.5, 0.6500000000000001, 0.5, 0.425, 0.5, 0.6500000000000001, 0.4, 0.36666666666666664, 0.5333333333333333, 0.5, 0.625, 0.5499999999999999, 0.7, 0.625, 0.4, 0.5499999999999999, 0.35, 0.4666666666666666, 0.9, 0.5, 0.375, 0.625, 0.9, 0.675, 0.5499999999999999, 0.6500000000000001, 0.4, 0.5666666666666667, 0.3, 0.75, 0.75, 0.4, 0.575, 0.6500000000000001, 0.2, 0.2, 0.625, 0.5333333333333333, 0.3, 0.75, 0.625]
acc = [0.7777777777777778, 0.4444444444444444, 0.8888888888888888, 0.6666666666666666, 0.3333333333333333, 0.4444444444444444, 0.625, 0.625, 0.75, 0.5, 0.6666666666666666, 0.5555555555555556, 0.4444444444444444, 0.5555555555555556, 0.6666666666666666, 0.4444444444444444, 0.375, 0.5, 0.5, 0.625, 0.5555555555555556, 0.6666666666666666, 0.6666666666666666, 0.4444444444444444, 0.5555555555555556, 0.3333333333333333, 0.5, 0.875, 0.5, 0.375, 0.6666666666666666, 0.8888888888888888, 0.6666666666666666, 0.5555555555555556, 0.6666666666666666, 0.4444444444444444, 0.625, 0.375, 0.75, 0.75, 0.4444444444444444, 0.5555555555555556, 0.6666666666666666, 0.2222222222222222, 0.2222222222222222, 0.6666666666666666, 0.5, 0.375, 0.75, 0.625]

# %% [markdown]
# #### Stepwise 2 Backward Model

# %%
box = box_plot([roc, acc], 'Second Stepwise Backward Model')
box.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="184672d2a0794eb7a9c83a3d0790a90d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_184672d2a0794eb7a9c83a3d0790a90d = echarts.init(
#                     document.getElementById('184672d2a0794eb7a9c83a3d0790a90d'), 'vintage', {renderer: 'canvas'});
#                 var option_184672d2a0794eb7a9c83a3d0790a90d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "boxplot",
#             "data": [
#                 [
#                     0.2,
#                     0.41874999999999996,
#                     0.5499999999999999,
#                     0.6500000000000001,
#                     0.9
#                 ],
#                 [
#                     0.2222222222222222,
#                     0.4444444444444444,
#                     0.5555555555555556,
#                     0.6666666666666666,
#                     0.8888888888888888
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "formatter": function(p){return p.name+'<br>'+'Min: '+                                                                                     p.value[1]+'<br>1st Quantile: '+p.value[2]+'<br>Median: '+p.value[3]+                                                                                     '<br>3rd Quantile: '+p.value[4]+'<br>Max: '+p.value[5]},
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "shadow"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": true,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": false,
#                 "areaStyle": {
#                     "opacity": 0
#                 }
#             },
#             "data": [
#                 "ROC",
#                 "Accuracy"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": true,
#                 "areaStyle": {
#                     "opacity": 1
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Second Stepwise Backward Model",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_184672d2a0794eb7a9c83a3d0790a90d.setOption(option_184672d2a0794eb7a9c83a3d0790a90d);
#         });
#     </script>

# %% [markdown]
# ###### prepare for data

# %%
roc = [0.325, 0.425, 0.6500000000000001, 0.45000000000000007, 0.22499999999999998, 0.9, 0.4, 0.5666666666666667, 0.625, 0.625, 0.525, 0.675, 0.2, 0.475, 0.525, 0.625, 0.5, 0.7333333333333333, 0.375, 0.375, 0.75, 0.675, 0.5499999999999999, 0.5499999999999999, 0.525, 0.45000000000000007, 0.7333333333333333, 0.5, 0.375, 0.625, 0.5499999999999999, 0.425, 0.5, 0.325, 0.7750000000000001, 0.6500000000000001, 0.7333333333333333, 0.5666666666666667, 0.5, 0.375, 0.6500000000000001, 0.425, 0.525, 0.3, 0.4, 0.6500000000000001, 0.8333333333333333, 0.7, 0.625, 0.625]
acc = [0.3333333333333333, 0.4444444444444444, 0.6666666666666666, 0.4444444444444444, 0.2222222222222222, 0.8888888888888888, 0.5, 0.625, 0.625, 0.625, 0.5555555555555556, 0.6666666666666666, 0.2222222222222222, 0.4444444444444444, 0.5555555555555556, 0.6666666666666666, 0.625, 0.75, 0.375, 0.375, 0.7777777777777778, 0.6666666666666666, 0.5555555555555556, 0.5555555555555556, 0.5555555555555556, 0.4444444444444444, 0.75, 0.625, 0.375, 0.625, 0.5555555555555556, 0.4444444444444444, 0.5555555555555556, 0.3333333333333333, 0.7777777777777778, 0.6666666666666666, 0.75, 0.625, 0.5, 0.375, 0.6666666666666666, 0.4444444444444444, 0.5555555555555556, 0.3333333333333333, 0.4444444444444444, 0.6666666666666666, 0.875, 0.625, 0.625, 0.625]

# %% [markdown]
# #### Stepwise 3 Forward Model

# %%
box = box_plot([roc, acc], 'Third Stepwise Forward Model')
box.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="92e3fb8b49df46b5a7eff29ee6153fa5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_92e3fb8b49df46b5a7eff29ee6153fa5 = echarts.init(
#                     document.getElementById('92e3fb8b49df46b5a7eff29ee6153fa5'), 'vintage', {renderer: 'canvas'});
#                 var option_92e3fb8b49df46b5a7eff29ee6153fa5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "boxplot",
#             "data": [
#                 [
#                     0.2,
#                     0.425,
#                     0.5375,
#                     0.6500000000000001,
#                     0.9
#                 ],
#                 [
#                     0.2222222222222222,
#                     0.4444444444444444,
#                     0.5555555555555556,
#                     0.6666666666666666,
#                     0.8888888888888888
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "formatter": function(p){return p.name+'<br>'+'Min: '+                                                                                     p.value[1]+'<br>1st Quantile: '+p.value[2]+'<br>Median: '+p.value[3]+                                                                                     '<br>3rd Quantile: '+p.value[4]+'<br>Max: '+p.value[5]},
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "shadow"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": true,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": false,
#                 "areaStyle": {
#                     "opacity": 0
#                 }
#             },
#             "data": [
#                 "ROC",
#                 "Accuracy"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": true,
#                 "areaStyle": {
#                     "opacity": 1
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Third Stepwise Forward Model",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_92e3fb8b49df46b5a7eff29ee6153fa5.setOption(option_92e3fb8b49df46b5a7eff29ee6153fa5);
#         });
#     </script>

# %% [markdown]
# ###### prepare for data

# %%
roc = [0.425, 0.2, 0.6500000000000001, 0.525, 0.22499999999999998, 0.875, 0.5333333333333333, 0.5666666666666667, 0.625, 0.625, 0.525, 0.7750000000000001, 0.3, 0.475, 0.425, 0.35, 0.2, 0.8333333333333333, 0.5, 0.5, 0.75, 0.5499999999999999, 0.425, 0.675, 0.625, 0.8, 0.8333333333333333, 0.3, 0.75, 0.375, 0.75, 0.525, 0.525, 0.25, 0.5499999999999999, 0.6500000000000001, 0.6666666666666666, 0.5666666666666667, 0.375, 0.625, 0.6500000000000001, 0.425, 0.3, 0.3, 0.625, 0.6500000000000001, 0.8333333333333333, 1.0, 0.625, 0.5]
acc = [0.4444444444444444, 0.2222222222222222, 0.6666666666666666, 0.5555555555555556, 0.2222222222222222, 0.8888888888888888, 0.5, 0.625, 0.625, 0.625, 0.5555555555555556, 0.7777777777777778, 0.3333333333333333, 0.4444444444444444, 0.4444444444444444, 0.3333333333333333, 0.25, 0.875, 0.5, 0.5, 0.7777777777777778, 0.5555555555555556, 0.4444444444444444, 0.6666666666666666, 0.6666666666666666, 0.7777777777777778, 0.875, 0.375, 0.75, 0.375, 0.7777777777777778, 0.5555555555555556, 0.5555555555555556, 0.2222222222222222, 0.5555555555555556, 0.6666666666666666, 0.75, 0.625, 0.375, 0.625, 0.6666666666666666, 0.4444444444444444, 0.3333333333333333, 0.3333333333333333, 0.6666666666666666, 0.6666666666666666, 0.875, 1.0, 0.625, 0.5]

# %% [markdown]
# #### Stepwise 3 Backward Model

# %%
box = box_plot([roc, acc], 'Third Stepwise Backward Model')
box.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="37fa8a1d985c4432bab9d2745aa948bf" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_37fa8a1d985c4432bab9d2745aa948bf = echarts.init(
#                     document.getElementById('37fa8a1d985c4432bab9d2745aa948bf'), 'vintage', {renderer: 'canvas'});
#                 var option_37fa8a1d985c4432bab9d2745aa948bf = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "boxplot",
#             "data": [
#                 [
#                     0.2,
#                     0.425,
#                     0.5499999999999999,
#                     0.6541666666666668,
#                     1.0
#                 ],
#                 [
#                     0.2222222222222222,
#                     0.4444444444444444,
#                     0.5555555555555556,
#                     0.6666666666666666,
#                     1.0
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "formatter": function(p){return p.name+'<br>'+'Min: '+                                                                                     p.value[1]+'<br>1st Quantile: '+p.value[2]+'<br>Median: '+p.value[3]+                                                                                     '<br>3rd Quantile: '+p.value[4]+'<br>Max: '+p.value[5]},
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "shadow"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": true,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": false,
#                 "areaStyle": {
#                     "opacity": 0
#                 }
#             },
#             "data": [
#                 "ROC",
#                 "Accuracy"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": true,
#                 "areaStyle": {
#                     "opacity": 1
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Third Stepwise Backward Model",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_37fa8a1d985c4432bab9d2745aa948bf.setOption(option_37fa8a1d985c4432bab9d2745aa948bf);
#         });
#     </script>

# %% [markdown]
# ### Final Model Visualization

# %% [markdown]
# ###### prepare for data

# %%
data = [[0.5555555555555556, 0.5555555555555556, 0.7777777777777778, 0.7777777777777778, 0.3333333333333333, 0.6666666666666666, 0.5, 0.75, 0.375, 0.625, 0.6666666666666666, 0.6666666666666666, 0.7777777777777778, 0.5555555555555556, 0.5555555555555556, 0.5555555555555556, 0.625, 0.625, 0.5, 0.5, 0.4444444444444444, 0.5555555555555556, 0.5555555555555556, 0.6666666666666666, 0.5555555555555556, 0.7777777777777778, 0.375, 0.75, 0.5, 0.25, 0.6666666666666666, 0.7777777777777778, 0.4444444444444444, 0.4444444444444444, 0.5555555555555556, 0.6666666666666666, 0.625, 0.5, 0.375, 0.375, 0.5555555555555556, 0.5555555555555556, 0.7777777777777778, 0.6666666666666666, 0.5555555555555556, 0.6666666666666666, 0.25, 0.75, 0.75, 0.375], [0.5, 0, 1.0, 0.75, 0.0, 1.0, 0.3333333333333333, 1.0, 0.0, 0.6666666666666666, 1.0, 0.6, 0.75, 0, 0.5, 0.5, 0.5, 0.5, 0, 0, 0.0, 0.5, 0, 1.0, 0.5, 1.0, 0.0, 1.0, 0.5, 0.25, 0.5714285714285714, 0.75, 0.42857142857142855, 0.0, 0.5, 0.6666666666666666, 0.5, 0.0, 0.3333333333333333, 0.3333333333333333, 0.5, 0.5, 0.75, 0.6, 0.5, 0.5714285714285714, 0.0, 0.6666666666666666, 1.0, 0.3333333333333333], [0.75, 0.0, 0.5, 0.75, 0.0, 0.25, 0.3333333333333333, 0.3333333333333333, 0.0, 0.5, 0.25, 0.75, 0.75, 0.0, 0.75, 0.25, 0.6666666666666666, 0.3333333333333333, 0.0, 0.0, 0.0, 0.75, 0.0, 0.25, 0.5, 0.5, 0.0, 0.3333333333333333, 0.25, 0.25, 1.0, 0.75, 0.75, 0.0, 0.25, 0.5, 0.6666666666666666, 0.0, 0.25, 0.25, 0.25, 0.5, 0.75, 0.75, 0.75, 1.0, 0.0, 0.6666666666666666, 0.5, 0.25], [0.4, 1.0, 1.0, 0.8, 0.6, 1.0, 0.6, 1.0, 0.75, 0.75, 1.0, 0.6, 0.8, 1.0, 0.4, 0.8, 0.6, 0.8, 1.0, 1.0, 0.8, 0.4, 1.0, 1.0, 0.6, 1.0, 0.6, 1.0, 0.75, 0.25, 0.4, 0.8, 0.2, 0.8, 0.8, 0.8, 0.6, 0.8, 0.5, 0.5, 0.8, 0.6, 0.8, 0.6, 0.4, 0.4, 0.4, 0.8, 1.0, 0.5]]

# %% [markdown]
# #### Visualization

# %%
box = box_plot(data)
box.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="780ad8af5db94941b9d01159488ef882" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_780ad8af5db94941b9d01159488ef882 = echarts.init(
#                     document.getElementById('780ad8af5db94941b9d01159488ef882'), 'vintage', {renderer: 'canvas'});
#                 var option_780ad8af5db94941b9d01159488ef882 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "boxplot",
#             "data": [
#                 [
#                     0.25,
#                     0.5,
#                     0.5555555555555556,
#                     0.6666666666666666,
#                     0.7777777777777778
#                 ],
#                 [
#                     0,
#                     0.1875,
#                     0.5,
#                     0.6875,
#                     1.0
#                 ],
#                 [
#                     0.0,
#                     0.1875,
#                     0.3333333333333333,
#                     0.75,
#                     1.0
#                 ],
#                 [
#                     0.2,
#                     0.575,
#                     0.8,
#                     1.0,
#                     1.0
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "formatter": function(p){return p.name+'<br>'+'Min: '+                                                                                     p.value[1]+'<br>1st Quantile: '+p.value[2]+'<br>Median: '+p.value[3]+                                                                                     '<br>3rd Quantile: '+p.value[4]+'<br>Max: '+p.value[5]},
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "shadow"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": true,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": false,
#                 "areaStyle": {
#                     "opacity": 0
#                 }
#             },
#             "data": [
#                 "Accuracy",
#                 "Precision",
#                 "Sensitivity",
#                 "Specificity"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": true,
#                 "areaStyle": {
#                     "opacity": 1
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Final Tree Model Evaluation",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_780ad8af5db94941b9d01159488ef882.setOption(option_780ad8af5db94941b9d01159488ef882);
#         });
#     </script>

# %% [markdown]
# ### Documentation

# %%
print('Python Version:', sys.version)
print('Pyecharts Version', pyecharts.__version__)
# Out:
# Python Version: 3.10.8 (tags/v3.10.8:aaaf517, Oct 11 2022, 16:50:30) [MSC v.1933 64 bit (AMD64)]
# Pyecharts Version 1.9.1
